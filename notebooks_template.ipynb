# %% [markdown]
# # Module N · Chapter X — <챕터 제목>
#
# 이 노트북은 7-블록 학습 구조의 **5번 블록(실습)** 을 담당합니다. 같은 디렉토리의 `<챕터>.md` 와 짝이 됩니다.
# - 본문(.md): 시나리오·Why·Where·직관·정의·수식·함정·다음 질문
# - 노트북(.ipynb): 직접 계산·시각화로 본문의 주장을 *눈으로 확인*
#
# 원칙
# 1. 시나리오와 같은 데이터를 쓴다 (학습자가 길을 잃지 않게).
# 2. 코드 한 줄마다 *왜 이 줄이 필요한지* 직전·직후 텍스트로 설명한다.
# 3. 수식이 등장하면 그 줄을 코드로도 직접 구현해 본 뒤, 라이브러리 함수로 같은 결과를 재현한다.

# %% [markdown]
# ## 0. 환경 준비
# 필요한 라이브러리만 import 합니다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

rng = np.random.default_rng(seed=42)
sns.set_theme(context="notebook", style="whitegrid")

# %% [markdown]
# ## 1. 시나리오 데이터
# 여기에 본문의 시나리오와 짝이 되는 데이터를 만들거나 읽어 옵니다.
#
# *예시*: `df = pd.read_csv("../../datasets/<도메인>/<파일>.csv")*

# %%
# TODO: 데이터 로드 또는 시뮬레이션

# %% [markdown]
# ## 2. 직관 — 그림 먼저
# 수식 전에 그림으로 *무엇이 일어나고 있는지* 본다.

# %%
# TODO: 시각화

# %% [markdown]
# ## 3. 손으로 계산해 보기
# 수식이 코드로 *어떻게 변환되는지* 한 줄씩 따라간다.

# %%
# TODO: 직접 계산

# %% [markdown]
# ## 4. 라이브러리로 같은 답 재현
# 직접 계산이 라이브러리 함수와 같은 결과를 내는지 확인한다 — *공식과 코드가 같은 것을 가리키고 있다*는 감각을 만든다.

# %%
# TODO: NumPy/SciPy/StatsModels 호출 비교

# %% [markdown]
# ## 5. 함정 점검
# 본문 6번 블록의 *Pitfalls* 를 데이터로 보여 주는 시뮬레이션.

# %%
# TODO: 잘못된 사용 예시 시뮬레이션

# %% [markdown]
# ## 6. 직접 답해 보기
# 오늘 다룬 개념을 *내 말로* 답하면서 reflection 으로 넘어간다.
#
# 1. 한 줄로 정리하면?
# 2. 같은 데이터를 다른 사람에게 설명한다면 첫 문장은 무엇으로 시작하겠는가?
# 3. 이 챕터의 도구가 *덜 적절한* 상황을 한 가지 떠올려 보자.
